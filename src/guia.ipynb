# %% [markdown]
# # Decission Tree

# %%
#EXTENSIVA

param_dist = {'n_estimators': randint(4,100),
              'criterion': ['gini','entropy','log_loss'],
              'max_depth': randint(-1, 20),
              'min_samples_split': randint(2,10),
              'min_samples_leaf': randint(2,10),
              'max_features': ['sqrt','log2',None]
              }

model = RandomForestClassifier()

random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_dist,
    n_iter=5,                  
    scoring='recall',
    cv=5,
    verbose=4,
    n_jobs=-1,
    random_state=123
)

random_search.fit(X_train_sel, y_train)

print("Mejores hiperparámetros:")
print(random_search.best_params_)

best_model = random_search.best_estimator_

# %%
#INTENSIVA 
param_grid = {'n_estimators': [18, 21, 25],
              'criterion': ['gini','entropy','log_loss'],
              'max_depth': [10, 11, 12, 13, 14],
              'min_samples_leaf': [3, 4, 5],
              }


# GridSearchCV
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=3,
    verbose=2,
    n_jobs=-1
)

grid_search.fit(X_train_sel,y_train)

print("Mejores hiperparámetros:")
print(grid_search.best_params_)

best_model2 = grid_search.best_estimator_

# %% [markdown]
# Instalaciones y Imports

# %% [markdown]
# Descripción de variables y carga de datos

# %% [markdown]
# ### Cribado Manual

# %% [markdown]
# Describe

# %% [markdown]
# Analizar valores sin sentido

# %% [markdown]
# FALTANTES

# %% [markdown]
# Train Test Split

# %% [markdown]
# Imputación de valores faltantes

# %% [markdown]
# Outliers

# %% [markdown]
# Correlaciones

# %% [markdown]
# Selección de Caracteristicas

# %% [markdown]
# ## Modelado

# %% [markdown]
# Decission Tree

# %% [markdown]
# Arbol por defecto

# %% [markdown]
# Plot - Grafico del arbol - Estructura

# %% [markdown]
# SHAP

# %% [markdown]
# Analizar resultados con matriz de confusión

# %% [markdown]
# ### Optimización

# %% [markdown]
# Busqueda Extensiva RandomizedSearchCV

# %% [markdown]
# Busqueda Intensiva

# %% [markdown]
# Plot

# %% [markdown]
# SHAP

# %% [markdown]
# Resultados
