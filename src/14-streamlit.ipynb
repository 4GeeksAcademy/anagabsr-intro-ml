# %%
# %pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit
#   Downloading streamlit-1.52.2-py3-none-any.whl (9.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 76.7 MB/s eta 0:00:00:00:0100:01
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.0.0-py3-none-any.whl (795 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.4/795.4 kB 62.0 MB/s eta 0:00:00
# Requirement already satisfied: blinker<2,>=1.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: numpy<3,>=1.23 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (2.3.5)
# Requirement already satisfied: packaging>=20 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (6.33.1)
# Requirement already satisfied: pyarrow>=7.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (22.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (2.32.5)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (4.15.0)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 24.6 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (3.1.45)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 71.0 MB/s eta 0:00:00:00:01
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in /home/vscode/.local/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Collecting jsonschema>=3.0 (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit)
#   Downloading jsonschema-4.26.0-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 22.9 MB/s eta 0:00:00
# Collecting narwhals>=1.27.1 (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit)
#   Downloading narwhals-2.15.0-py3-none-any.whl (432 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.9/432.9 kB 44.3 MB/s eta 0:00:00
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/vscode/.local/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/vscode/.local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.11/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Collecting attrs>=22.2.0 (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit)
#   Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 20.2 MB/s eta 0:00:00
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit)
#   Downloading jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit)
#   Downloading referencing-0.37.0-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.25.0 (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit)
#   Downloading rpds_py-0.30.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.8/390.8 kB 58.9 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Installing collected packages: watchdog, toml, tenacity, rpds-py, narwhals, attrs, referencing, pydeck, jsonschema-specifications, jsonschema, altair, streamlit
# Successfully installed altair-6.0.0 attrs-25.4.0 jsonschema-4.26.0 jsonschema-specifications-2025.9.1 narwhals-2.15.0 pydeck-0.9.1 referencing-0.37.0 rpds-py-0.30.0 streamlit-1.52.2 tenacity-9.1.2 toml-0.10.2 watchdog-6.0.0
#
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st

# %%
st.set_page_config(page_title="Calculadora de Gross Profit", layout="centered")

st.title("🧮 Calculadora de Gross Profit")
st.write("Introduce los valores para obtener el Gross Profit, el margen actual y compararlo con tu margen objetivo.")

# Layout en columnas
col1, col2 = st.columns(2)

with col1:
    revenue = st.number_input("Revenue (Ingresos)", min_value=0.0, step=100.0)
with col2:
    cogs = st.number_input("COGS (Coste de bienes vendidos)", min_value=0.0, step=100.0)

st.divider()
# Out:
# 2026-01-08 08:00:04.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:04.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
target_margin = st.number_input(
    "Margen bruto objetivo (%)",
    min_value=0.0,
    max_value=100.0,
    value=30.0,
    step=1.0,
    help="Introduce el margen bruto que te gustaría conseguir sobre el revenue."
)
# Out:
# 2026-01-08 08:00:25.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:25.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:25.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:25.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:25.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:25.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:00:25.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if revenue == 0:
    st.info("Introduce un Revenue mayor que 0 para calcular los indicadores.")
else:
    # Aquí se define gross_profit y gross_margin
    gross_profit = revenue - cogs
    gross_margin = (gross_profit / revenue) * 100

    st.subheader("📊 Resultados actuales")
    col_r1, col_r2, col_r3 = st.columns(3)
    with col_r1:
        st.metric("Gross Profit", f"{gross_profit:,.2f} €")
    with col_r2:
        st.metric("Gross Margin actual", f"{gross_margin:.2f} %")
    with col_r3:
        st.metric("Margen objetivo", f"{target_margin:.2f} %")

    if cogs > revenue:
        st.warning(
            "El COGS es mayor que el Revenue, el Gross Profit es negativo. "
            "Revisa precios, descuentos o estructura de costes."
        )

    if gross_margin < target_margin:
        st.error(
            f"El margen actual ({gross_margin:.2f} %) está por debajo del margen objetivo ({target_margin:.2f} %)."
        )
    else:
        st.success(
            f"El margen actual ({gross_margin:.2f} %) está en línea o por encima del objetivo ({target_margin:.2f} %)."
        )

    st.divider()
# Out:
# 2026-01-08 08:01:22.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:01:22.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:01:22.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
cogs_max_for_target = revenue * (1 - target_margin / 100)

st.subheader("🔍 Análisis de margen objetivo")

col_a1, col_a2 = st.columns(2)
with col_a1:
        st.write(f"**COGS actual:** {cogs:,.2f} €")
        st.write(f"**COGS máximo para margen objetivo:** {cogs_max_for_target:,.2f} €")
with col_a2:
        diff_cogs = cogs - cogs_max_for_target
        if diff_cogs > 0:
            st.write(
                f"Para alcanzar el margen objetivo, deberías reducir el COGS en aproximadamente "
                f"**{diff_cogs:,.2f} €** o aumentar precios."
            )
        else:
            st.write(
                "Con el COGS actual estás dentro del rango para cumplir o superar el margen objetivo."
            )
# Out:
# 2026-01-08 08:02:04.462 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-08 08:02:04.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
